# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta

# %%
today = date.today()

# %%
d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=730)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

# %%
data = yf.download('INR=X', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)

# %%
data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
print(data.head())
# Out:
#         Date       Open       High        Low      Close  Adj Close  Volume
# 0 2020-09-21  73.534798  73.649597  73.278000  73.534798  73.534798       0
# 1 2020-09-22  73.579803  73.650002  73.388000  73.579803  73.579803       0
# 2 2020-09-23  73.502899  73.800003  73.438004  73.502998  73.502998       0
# 3 2020-09-24  74.010002  74.222000  73.563004  73.778397  73.778397       0
# 4 2020-09-25  73.910004  73.910004  73.561501  73.682404  73.682404       0

# %%
data.shape
# Out:
# (522, 7)

# %%
import plotly.graph_objects as go
figure = go.Figure(data=[go.Candlestick(x=data["Date"],
                                        open=data["Open"], 
                                        high=data["High"],
                                        low=data["Low"], 
                                        close=data["Close"])])
figure.update_layout(title = "USD_INR Price Analysis", 
                     xaxis_rangeslider_visible=False)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="668f854f-cf7c-401c-b418-5b6256331f1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("668f854f-cf7c-401c-b418-5b6256331f1f")) {                    Plotly.newPlot(                        "668f854f-cf7c-401c-b418-5b6256331f1f",                        [{"close":[73.53479766845703,73.57980346679688,73.50299835205078,73.77839660644531,73.68240356445312,73.69930267333984,73.9749984741211,73.84500122070312,73.70500183105469,73.21700286865234,73.32240295410156,73.1082992553711,73.81500244140625,73.5425033569336,73.28050231933594,73.01480102539062,73.35079956054688,73.62000274658203,73.29620361328125,73.37100219726562,73.44380187988281,73.57499694824219,73.64749908447266,73.6812973022461,73.72000122070312,73.8228988647461,73.94850158691406,73.80500030517578,74.44000244140625,74.26399993896484,74.55049896240234,74.45680236816406,74.65560150146484,74.37999725341797,74.12000274658203,73.97979736328125,73.95320129394531,74.28160095214844,74.56999969482422,74.86499786376953,74.48770141601562,74.41809844970703,74.47969818115234,74.41999816894531,74.09960174560547,74.16239929199219,74.24490356445312,73.96080017089844,73.77989959716797,74.04879760742188,73.94090270996094,74.02519989013672,73.65499877929688,73.66259765625,73.86489868164062,73.79029846191406,74.0199966430664,73.72640228271484,73.93499755859375,73.72669982910156,73.73799896240234,73.86000061035156,73.75980377197266,73.6166000366211,73.52980041503906,73.60359954833984,73.935302734375,74.2699966430664,73.83979797363281,73.55780029296875,73.68900299072266,73.5448989868164,73.45359802246094,73.13400268554688,73.08920288085938,73.09200286865234,73.31999969482422,73.37480163574219,73.36000061035156,73.44599914550781,73.37339782714844,73.51349639892578,73.16500091552734,73.1698989868164,73.08760070800781,73.15899658203125,73.1886978149414,73.19190216064453,72.91089630126953,72.95490264892578,72.99590301513672,72.97000122070312,72.91999816894531,73.03710174560547,72.93879699707031,72.90660095214844,73.11979675292969,72.91629791259766,72.85800170898438,72.9457015991211,72.78479766845703,72.92990112304688,72.85489654541016,72.80729675292969,72.70950317382812,72.59480285644531,72.63870239257812,72.93499755859375,72.79730224609375,72.60540008544922,72.5530014038086,72.44400024414062,72.37699890136719,72.4000015258789,73.1509017944336,73.59590148925781,73.30940246582031,73.27749633789062,72.88069915771484,73.13179779052734,73.1333999633789,73.33000183105469,72.7759017944336,72.70600128173828,72.63899993896484,72.68299865722656,72.51529693603516,72.5156021118164,72.29560089111328,72.6688003540039,72.40499877929688,72.38050079345703,72.61219787597656,72.64559936523438,72.61280059814453,72.44719696044922,72.74189758300781,73.44529724121094,73.20349884033203,73.28730010986328,73.3759994506836,73.27950286865234,73.48999786376953,74.40149688720703,74.54450225830078,74.72949981689453,74.99099731445312,75.18150329589844,75.0261001586914,74.72740173339844,74.56320190429688,74.8781967163086,75.44920349121094,75.42949676513672,75.0916976928711,74.86810302734375,74.81490325927734,74.57499694824219,74.31179809570312,74.10579681396484,74.09480285644531,73.8375015258789,73.77890014648438,73.79940032958984,73.61519622802734,73.29029846191406,73.5,73.3750991821289,73.68160247802734,73.44490051269531,73.27890014648438,73.26969909667969,73.1281967163086,73.222900390625,73.02189636230469,72.90979766845703,72.83660125732422,72.80490112304688,72.67250061035156,72.68299865722656,72.39350128173828,72.48719787597656,72.8550033569336,72.96510314941406,73.04419708251953,72.90969848632812,72.80940246582031,72.97530364990234,72.98529815673828,73.01229858398438,73.23159790039062,73.18080139160156,73.3447036743164,73.8240966796875, ...

# %%
correlation = data.corr()
print(correlation["Close"].sort_values(ascending=False))
# Out:
# Close        1.000000
# Adj Close    1.000000
# Open         0.999641
# Low          0.997297
# High         0.996949
# Volume            NaN
# Name: Close, dtype: float64

# %%
from autots import AutoTS
model = AutoTS(forecast_length=5, frequency='infer', ensemble='simple')
model = model.fit(data, date_col='Date', value_col='Close', id_col=None)
prediction = model.predict()
forecast = prediction.forecast
print(forecast)
# Out:
# Inferred frequency is: B
# Model Number: 1 with model ARIMA in generation 0 of 10
# Model Number: 2 with model ARIMA in generation 0 of 10
# Model Number: 3 with model ARIMA in generation 0 of 10
# Model Number: 4 with model AverageValueNaive in generation 0 of 10
# Model Number: 5 with model AverageValueNaive in generation 0 of 10
# Model Number: 6 with model AverageValueNaive in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# Model Number: 8 with model DatepartRegression in generation 0 of 10
# Model Number: 9 with model DatepartRegression in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 10 with model DatepartRegression in generation 0 of 10
# Epoch 1/50
# 17/17 [==============================] - 7s 6ms/step - loss: 0.4002
# Epoch 2/50
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3960
# Epoch 3/50
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3966
# Epoch 4/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3960
# Epoch 5/50
# 17/17 [==============================] - 0s 6ms/step - loss: 0.3950
# Epoch 6/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3931
# Epoch 7/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3949
# Epoch 8/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3896
# Epoch 9/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3881
# Epoch 10/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3849
# Epoch 11/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3811
# Epoch 12/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3753
# Epoch 13/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3720
# Epoch 14/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3641
# Epoch 15/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3598
# Epoch 16/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3543
# Epoch 17/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3600
# Epoch 18/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3552
# Epoch 19/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3608
# Epoch 20/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3566
# Epoch 21/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3539
# Epoch 22/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3462
# Epoch 23/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3525
# Epoch 24/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3512
# Epoch 25/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3490
# Epoch 26/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3483
# Epoch 27/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3507
# Epoch 28/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3514
# Epoch 29/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3497
# Epoch 30/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3477
# Epoch 31/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3495
# Epoch 32/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3489
# Epoch 33/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3451
# Epoch 34/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3502
# Epoch 35/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3455
# Epoch 36/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3540
# Epoch 37/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3423
# Epoch 38/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3462
# Epoch 39/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3526
# Epoch 40/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3482
# Epoch 41/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3472
# Epoch 42/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3486
# Epoch 43/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3518
# Epoch 44/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3437
# Epoch 45/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3510
# Epoch 46/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3485
# Epoch 47/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3452
# Epoch 48/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3471
# Epoch 49/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3448
# Epoch 50/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3456
# Model Number: 11 with model ETS in generation 0 of 10
# Model Number: 12 with model ETS in generation 0 of 10
# Model Number: 13 with model GLM in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/links.py:188: RuntimeWarning:
#
# overflow encountered in exp
# Template Eval Error: ValueError('shapes (5,55) and (58,) not aligned: 55 (dim 1) != 58 (dim 0)') in model 13: GLM
# Model Number: 14 with model GLM in generation 0 of 10
# Model Number: 15 with model GLS in generation 0 of 10
# Model Number: 16 with model GLS in generation 0 of 10
# Model Number: 17 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 17: GluonTS
# Model Number: 18 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 18: GluonTS
# Model Number: 19 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 19: GluonTS
# Model Number: 20 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 20: GluonTS
# Model Number: 21 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 21: GluonTS
# Model Number: 22 with model LastValueNaive in generation 0 of 10
# Model Number: 23 with model LastValueNaive in generation 0 of 10
# Model Number: 24 with model LastValueNaive in generation 0 of 10
# Model Number: 25 with model LastValueNaive in generation 0 of 10
# Model Number: 26 with model SeasonalNaive in generation 0 of 10
# Model Number: 27 with model SeasonalNaive in generation 0 of 10
# Model Number: 28 with model SeasonalNaive in generation 0 of 10
# Model Number: 29 with model UnobservedComponents in generation 0 of 10
# Model Number: 30 with model UnobservedComponents in generation 0 of 10
# Model Number: 31 with model UnobservedComponents in generation 0 of 10
# Model Number: 32 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 32: VAR
# Model Number: 33 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 33: VAR
# Model Number: 34 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 34: VECM
# Model Number: 35 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 35: VECM
# Model Number: 36 with model WindowRegression in generation 0 of 10
# Model Number: 37 with model ConstantNaive in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 38 with model FBProphet in generation 0 of 10
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/13ia9f2d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/ovqs_uvi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50330', 'data', 'file=/tmp/tmp1bm0dyn5/13ia9f2d.json', 'init=/tmp/tmp1bm0dyn5/ovqs_uvi.json', 'output', 'file=/tmp/tmpuk8hr0zu/prophet_model-20220921062846.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:28:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:28:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Model Number: 39 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 39: GluonTS
# Model Number: 40 with model MultivariateRegression in generation 0 of 10
# [Parallel(n_jobs=-2)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 200 out of 200 | elapsed:    0.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# Model Number: 41 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 41: MultivariateRegression
# Model Number: 42 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 42: DatepartRegression
# Model Number: 43 with model SeasonalNaive in generation 0 of 10
# Model Number: 44 with model DatepartRegression in generation 0 of 10
# Model Number: 45 with model UnobservedComponents in generation 0 of 10
# Model Number: 46 with model UnobservedComponents in generation 0 of 10
# Model Number: 47 with model ETS in generation 0 of 10
# Model Number: 48 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 48: VECM
# Model Number: 49 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/api.py)") in model 49: ARDL
# Model Number: 50 with model MultivariateMotif in generation 0 of 10
# Model Number: 51 with model MultivariateMotif in generation 0 of 10
# Model Number: 52 with model UnivariateMotif in generation 0 of 10
# Model Number: 53 with model UnivariateMotif in generation 0 of 10
# Model Number: 54 with model SectionalMotif in generation 0 of 10
# Model Number: 55 with model SectionalMotif in generation 0 of 10
# Model Number: 56 with model MultivariateRegression in generation 0 of 10
# Model Number: 57 with model FBProphet in generation 0 of 10
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/rjzl3df1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/0di6_ycn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67631', 'data', 'file=/tmp/tmp1bm0dyn5/rjzl3df1.json', 'init=/tmp/tmp1bm0dyn5/0di6_ycn.json', 'output', 'file=/tmp/tmp1gif5klz/prophet_model-20220921062850.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:28:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:28:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Model Number: 58 with model SeasonalNaive in generation 0 of 10
# Model Number: 59 with model DatepartRegression in generation 0 of 10
# [Parallel(n_jobs=-2)]: Using backend SequentialBackend with 1 concurrent workers.
# Template Eval Error: ValueError('X has 55 features, but RandomForestRegressor is expecting 58 features as input.') in model 59: DatepartRegression
# Model Number: 60 with model NVAR in generation 0 of 10
# [Parallel(n_jobs=-2)]: Done 100 out of 100 | elapsed:    0.3s finished
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:493: FutureWarning:
#
# The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - weekdayofmonth_1
# - weekdayofmonth_4
# - weekdayofmonth_5
# Model Number: 61 with model Theta in generation 0 of 10
# Model Number: 62 with model UnivariateRegression in generation 0 of 10
# Model Number: 63 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 63: ARCH
# Model Number: 64 with model ConstantNaive in generation 0 of 10
# Model Number: 65 with model LastValueNaive in generation 0 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 65: LastValueNaive
# Model Number: 66 with model AverageValueNaive in generation 0 of 10
# Model Number: 67 with model GLS in generation 0 of 10
# Model Number: 68 with model SeasonalNaive in generation 0 of 10
# Model Number: 69 with model GLM in generation 0 of 10
# Model Number: 70 with model ETS in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:1444: RuntimeWarning:
#
# invalid value encountered in log
#
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/xzo9nvw5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/phgp2zdw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58811', 'data', 'file=/tmp/tmp1bm0dyn5/xzo9nvw5.json', 'init=/tmp/tmp1bm0dyn5/phgp2zdw.json', 'output', 'file=/tmp/tmp02o6frsi/prophet_model-20220921062854.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:28:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# Model Number: 71 with model FBProphet in generation 0 of 10
# 06:28:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Model Number: 72 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 72: GluonTS
# Model Number: 73 with model UnobservedComponents in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 73: UnobservedComponents
# Model Number: 74 with model VAR in generation 0 of 10
# Template Eval Error: IndexError('tuple index out of range') in model 74: VAR
# Model Number: 75 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 75: VECM
# Model Number: 76 with model ARIMA in generation 0 of 10
# Model Number: 77 with model WindowRegression in generation 0 of 10
# Model Number: 78 with model DatepartRegression in generation 0 of 10
# Template Eval Error: Exception('Transformer DatepartRegression failed on fit') in model 78: DatepartRegression
# Model Number: 79 with model UnivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 79: UnivariateRegression
# Model Number: 80 with model MultivariateRegression in generation 0 of 10
# Model Number: 81 with model UnivariateMotif in generation 0 of 10
# Model Number: 82 with model MultivariateMotif in generation 0 of 10
# Model Number: 83 with model SectionalMotif in generation 0 of 10
# Template Eval Error: ValueError("regression_type=='User' but no future_regressor supplied") in model 83: SectionalMotif
# Model Number: 84 with model NVAR in generation 0 of 10
# Model Number: 85 with model Theta in generation 0 of 10
# Model Number: 86 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/api.py)") in model 86: ARDL
# Model Number: 87 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 87: ARCH
# Model Number: 88 with model Theta in generation 0 of 10
# Model Number: 89 with model ConstantNaive in generation 0 of 10
# Model Number: 90 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 90: ARCH
# Model Number: 91 with model UnivariateRegression in generation 0 of 10
# Model Number: 92 with model SeasonalNaive in generation 0 of 10
# Model Number: 93 with model LastValueNaive in generation 0 of 10
# Model Number: 94 with model SeasonalNaive in generation 0 of 10
# Model Number: 95 with model ConstantNaive in generation 0 of 10
# Model Number: 96 with model UnivariateMotif in generation 0 of 10
# Model Number: 97 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 97: ARCH
# Model Number: 98 with model GLM in generation 0 of 10
# Model Number: 99 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 99: GluonTS
# Model Number: 100 with model VAR in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VAR') in model 100: VAR
# Model Number: 101 with model ARDL in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 101: ARDL
# Model Number: 102 with model GLS in generation 0 of 10
# Model Number: 103 with model SectionalMotif in generation 0 of 10
# Model Number: 104 with model NVAR in generation 0 of 10
# Model Number: 105 with model GLM in generation 0 of 10
# Model Number: 106 with model DatepartRegression in generation 0 of 10
# Template Eval Error: Exception('Transformer DatepartRegression failed on fit') in model 106: DatepartRegression
# Model Number: 107 with model SectionalMotif in generation 0 of 10
# Model Number: 108 with model ConstantNaive in generation 0 of 10
# Model Number: 109 with model LastValueNaive in generation 0 of 10
# Model Number: 110 with model LastValueNaive in generation 0 of 10
# Model Number: 111 with model Theta in generation 0 of 10
# Model Number: 112 with model ETS in generation 0 of 10
# ETS error ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# ETS failed on Close with ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# Model Number: 113 with model UnivariateMotif in generation 0 of 10
# Model Number: 114 with model UnivariateRegression in generation 0 of 10
# Model Number: 115 with model ETS in generation 0 of 10
# Model Number: 116 with model WindowRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 116: WindowRegression
# Model Number: 117 with model MultivariateRegression in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/sklearn/experimental/enable_hist_gradient_boosting.py:17: UserWarning:
#
# Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
# Model Number: 118 with model Theta in generation 0 of 10
# Template Eval Error: Exception('Transformer Detrend failed on fit') in model 118: Theta
# Model Number: 119 with model UnobservedComponents in generation 0 of 10
# Model Number: 120 with model ConstantNaive in generation 0 of 10
# Model Number: 121 with model MultivariateRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 121: MultivariateRegression
# Model Number: 122 with model SeasonalNaive in generation 0 of 10
# Model Number: 123 with model SectionalMotif in generation 0 of 10
# Model Number: 124 with model LastValueNaive in generation 0 of 10
# Model Number: 125 with model SeasonalNaive in generation 0 of 10
# Model Number: 126 with model DatepartRegression in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 126: DatepartRegression
# Model Number: 127 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 127: GluonTS
# Model Number: 128 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 128: ARCH
# Model Number: 129 with model Theta in generation 0 of 10
# Model Number: 130 with model WindowRegression in generation 0 of 10
# Model Number: 131 with model GLM in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=3.1976e-25): result may not be accurate.
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 131: GLM
# Model Number: 132 with model AverageValueNaive in generation 0 of 10
# Model Number: 133 with model LastValueNaive in generation 0 of 10
# Model Number: 134 with model MultivariateRegression in generation 0 of 10
# Epoch 1/100
# 17/17 [==============================] - 7s 24ms/step - loss: 0.1930
# Epoch 2/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1732
# Epoch 3/100
# 17/17 [==============================] - 0s 27ms/step - loss: 0.1556
# Epoch 4/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.1439
# Epoch 5/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.1209
# Epoch 6/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0992
# Epoch 7/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0858
# Epoch 8/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0720
# Epoch 9/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0607
# Epoch 10/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0569
# Epoch 11/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0562
# Epoch 12/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0529
# Epoch 13/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0539
# Epoch 14/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0494
# Epoch 15/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0525
# Epoch 16/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0532
# Epoch 17/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0481
# Epoch 18/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0461
# Epoch 19/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0484
# Epoch 20/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0482
# Epoch 21/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0507
# Epoch 22/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0494
# Epoch 23/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0463
# Epoch 24/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0461
# Epoch 25/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0471
# Epoch 26/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0467
# Epoch 27/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0479
# Epoch 28/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0492
# Epoch 29/100
# 17/17 [==============================] - 0s 26ms/step - loss: 0.0447
# Epoch 30/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0441
# Epoch 31/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0460
# Epoch 32/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0455
# Epoch 33/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0447
# Epoch 34/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0452
# Epoch 35/100
# 17/17 [==============================] - 0s 28ms/step - loss: 0.0445
# Epoch 36/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0420
# Epoch 37/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0453
# Epoch 38/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0430
# Epoch 39/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0444
# Epoch 40/100
# 17/17 [==============================] - 0s 26ms/step - loss: 0.0438
# Epoch 41/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0415
# Epoch 42/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0444
# Epoch 43/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0440
# Epoch 44/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0433
# Epoch 45/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0444
# Epoch 46/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0410
# Epoch 47/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0458
# Epoch 48/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0422
# Epoch 49/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0401
# Epoch 50/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0443
# Epoch 51/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0421
# Epoch 52/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0440
# Epoch 53/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0410
# Epoch 54/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0436
# Epoch 55/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0417
# Epoch 56/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0431
# Epoch 57/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0435
# Epoch 58/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0403
# Epoch 59/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0436
# Epoch 60/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0407
# Epoch 61/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0436
# Epoch 62/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0419
# Epoch 63/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0454
# Epoch 64/100
# 17/17 [==============================] - 0s 26ms/step - loss: 0.0402
# Epoch 65/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0407
# Epoch 66/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0394
# Epoch 67/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0434
# Epoch 68/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0425
# Epoch 69/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0415
# Epoch 70/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0425
# Epoch 71/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0415
# Epoch 72/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0409
# Epoch 73/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0408
# Epoch 74/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0403
# Epoch 75/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0424
# Epoch 76/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0418
# Epoch 77/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0406
# Epoch 78/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0405
# Epoch 79/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0397
# Epoch 80/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0403
# Epoch 81/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0418
# Epoch 82/100
# 17/17 [==============================] - 0s 25ms/step - loss: 0.0398
# Epoch 83/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0405
# Epoch 84/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0410
# Epoch 85/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0408
# Epoch 86/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0411
# Epoch 87/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0388
# Epoch 88/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0401
# Epoch 89/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0393
# Epoch 90/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0403
# Epoch 91/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0400
# Epoch 92/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0404
# Epoch 93/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0391
# Epoch 94/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0382
# Epoch 95/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0387
# Epoch 96/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0400
# Epoch 97/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0414
# Epoch 98/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0393
# Epoch 99/100
# 17/17 [==============================] - 0s 23ms/step - loss: 0.0404
# Epoch 100/100
# 17/17 [==============================] - 0s 24ms/step - loss: 0.0394
# Model Number: 135 with model UnobservedComponents in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=3.1976e-25): result may not be accurate.
# Model Number: 136 with model MultivariateMotif in generation 0 of 10
# Model Number: 137 with model MultivariateMotif in generation 0 of 10
# No anomalies detected.
# Model Number: 138 with model ConstantNaive in generation 0 of 10
# Model Number: 139 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 139: VECM
# Model Number: 140 with model MultivariateMotif in generation 0 of 10
# Model Number: 141 with model SectionalMotif in generation 0 of 10
# Model Number: 142 with model UnobservedComponents in generation 0 of 10
# Model Number: 143 with model SectionalMotif in generation 0 of 10
# Model Number: 144 with model UnobservedComponents in generation 0 of 10
# Model Number: 145 with model UnivariateMotif in generation 0 of 10
# Model Number: 146 with model ETS in generation 0 of 10
# Model Number: 147 with model LastValueNaive in generation 0 of 10
# Model Number: 148 with model UnobservedComponents in generation 0 of 10
# Model Number: 149 with model ETS in generation 0 of 10
# Model Number: 150 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 150: GLM
# Model Number: 151 with model GLS in generation 0 of 10
# Model Number: 152 with model ConstantNaive in generation 0 of 10
# Model Number: 153 with model ARDL in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:1231: RuntimeWarning:
#
# invalid value encountered in log
# Template Eval Error: Exception('Transformer SinTrend failed on fit') in model 153: ARDL
# Model Number: 154 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 154: GluonTS
# Model Number: 155 with model SeasonalNaive in generation 0 of 10
# Model Number: 156 with model ARIMA in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but future_regressor not supplied") in model 156: ARIMA
# Model Number: 157 with model ConstantNaive in generation 0 of 10
# Model Number: 158 with model ARIMA in generation 0 of 10
# Model Number: 159 with model LastValueNaive in generation 0 of 10
# Model Number: 160 with model GluonTS in generation 0 of 10
# Template Eval Error: ImportError('GluonTS installation not found or installed version is incompatible with AutoTS.') in model 160: GluonTS
# Model Number: 161 with model LastValueNaive in generation 0 of 10
# Model Number: 162 with model ARCH in generation 0 of 10
# Template Eval Error: ImportError('`arch` package must be installed from pip') in model 162: ARCH
# Model Number: 163 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('regression_type=user and no future_regressor passed') in model 163: GLM
# Model Number: 164 with model ConstantNaive in generation 0 of 10
# Model Number: 165 with model WindowRegression in generation 0 of 10
# Model Number: 166 with model UnivariateRegression in generation 0 of 10
# Model Number: 167 with model AverageValueNaive in generation 0 of 10
# Model Number: 168 with model VECM in generation 0 of 10
# Template Eval Error: ValueError('Only gave one variable to VECM') in model 168: VECM
# Model Number: 169 with model SectionalMotif in generation 0 of 10
# Model Number: 170 with model VECM in generation 0 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor supplied") in model 170: VECM
# Model Number: 171 with model GluonTS in generation 0 of 10
# Template Eval Error: Exception('Transformer RobustScaler failed on fit') in model 171: GluonTS
# Model Number: 172 with model UnivariateMotif in generation 0 of 10
# Model Number: 173 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/api.py)") in model 173: ARDL
# Model Number: 174 with model MultivariateMotif in generation 0 of 10
# Model Number: 175 with model MultivariateMotif in generation 0 of 10
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning:
#
# Feature names only support names that are all strings. Got feature names with dtypes: ['Timestamp', 'str']. An error will be raised in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py:1120: RuntimeWarning:
#
# All-NaN slice encountered
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py:1376: RuntimeWarning:
#
# All-NaN slice encountered
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning:
#
# Feature names only support names that are all strings. Got feature names with dtypes: ['Timestamp', 'str']. An error will be raised in 1.2.
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/links.py:517: RuntimeWarning:
#
# overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/families/family.py:134: RuntimeWarning:
#
# invalid value encountered in multiply
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/genmod/generalized_linear_model.py:1199: RuntimeWarning:
#
# invalid value encountered in multiply
# Model Number: 176 with model GLM in generation 0 of 10
# Template Eval Error: ValueError('NaN, inf or invalid value detected in weights, estimation infeasible.') in model 176: GLM
# Model Number: 177 with model GLS in generation 0 of 10
# Model Number: 178 with model VAR in generation 0 of 10
# Template Eval Error: IndexError('tuple index out of range') in model 178: VAR
# Model Number: 179 with model UnivariateMotif in generation 0 of 10
# Model Number: 180 with model MultivariateMotif in generation 0 of 10
# Model Number: 181 with model SeasonalNaive in generation 0 of 10
# Model Number: 182 with model UnivariateMotif in generation 0 of 10
# Template Eval Error: Exception('Transformer DatepartRegression failed on inverse') in model 182: UnivariateMotif
# Model Number: 183 with model ARDL in generation 0 of 10
# Template Eval Error: ImportError("cannot import name 'ARDL' from 'statsmodels.tsa.api' (/usr/local/lib/python3.7/dist-packages/statsmodels/tsa/api.py)") in model 183: ARDL
# New Generation: 1 of 10
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:493: FutureWarning:
#
# The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names seen at fit time, yet now missing:
# - weekdayofmonth_1
# - weekdayofmonth_4
# - weekdayofmonth_5
# Model Number: 184 with model AverageValueNaive in generation 1 of 10
# Model Number: 185 with model LastValueNaive in generation 1 of 10
# Model Number: 186 with model GLM in generation 1 of 10
# Model Number: 187 with model UnivariateMotif in generation 1 of 10
# Model Number: 188 with model UnivariateMotif in generation 1 of 10
# Model Number: 189 with model AverageValueNaive in generation 1 of 10
# Model Number: 190 with model UnivariateMotif in generation 1 of 10
# Model Number: 191 with model ConstantNaive in generation 1 of 10
# Model Number: 192 with model LastValueNaive in generation 1 of 10
# Model Number: 193 with model NVAR in generation 1 of 10
# Model Number: 194 with model LastValueNaive in generation 1 of 10
# Model Number: 195 with model UnivariateRegression in generation 1 of 10
# Model Number: 196 with model ConstantNaive in generation 1 of 10
# Model Number: 197 with model MultivariateRegression in generation 1 of 10
# Template Eval Error: ValueError('Some value(s) of y are out of the valid range for family PoissonDistribution') in model 197: MultivariateRegression
# Model Number: 198 with model AverageValueNaive in generation 1 of 10
# Model Number: 199 with model GLM in generation 1 of 10
# Model Number: 200 with model LastValueNaive in generation 1 of 10
# Model Number: 201 with model UnobservedComponents in generation 1 of 10
# Model Number: 202 with model ETS in generation 1 of 10
# Model Number: 203 with model UnobservedComponents in generation 1 of 10
# Model Number: 204 with model ETS in generation 1 of 10
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=3.1976e-25): result may not be accurate.
# Model Number: 205 with model DatepartRegression in generation 1 of 10
# Model Number: 206 with model ConstantNaive in generation 1 of 10
# Model Number: 207 with model UnobservedComponents in generation 1 of 10
# Model Number: 208 with model NVAR in generation 1 of 10
# Model Number: 209 with model SectionalMotif in generation 1 of 10
# Model Number: 210 with model AverageValueNaive in generation 1 of 10
# Model Number: 211 with model ConstantNaive in generation 1 of 10
# Model Number: 212 with model MultivariateMotif in generation 1 of 10
# Model Number: 213 with model GLM in generation 1 of 10
# Model Number: 214 with model DatepartRegression in generation 1 of 10
# Model Number: 215 with model SeasonalNaive in generation 1 of 10
# Model Number: 216 with model GLS in generation 1 of 10
# Model Number: 217 with model MultivariateMotif in generation 1 of 10
# Model Number: 218 with model UnivariateRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but not future_regressor supplied.") in model 218: UnivariateRegression
# Model Number: 219 with model ETS in generation 1 of 10
# ETS error ValueError('Can only dampen the trend component')
# ETS failed on Close with ValueError('Can only dampen the trend component')
# Model Number: 220 with model MultivariateRegression in generation 1 of 10
# Model Number: 221 with model NVAR in generation 1 of 10
# Model Number: 222 with model GLS in generation 1 of 10
# Model Number: 223 with model Theta in generation 1 of 10
# Model Number: 224 with model GLS in generation 1 of 10
# Model Number: 225 with model UnivariateMotif in generation 1 of 10
# Model Number: 226 with model MultivariateRegression in generation 1 of 10
# Model Number: 227 with model MultivariateMotif in generation 1 of 10
# Model Number: 228 with model ARIMA in generation 1 of 10
# Model Number: 229 with model MultivariateRegression in generation 1 of 10
# Template Eval Error: ValueError('Some value(s) of y are out of the valid range for family PoissonDistribution') in model 229: MultivariateRegression
# Model Number: 230 with model GLS in generation 1 of 10
# Model Number: 231 with model Theta in generation 1 of 10
# Model Number: 232 with model SeasonalNaive in generation 1 of 10
# Model Number: 233 with model ARIMA in generation 1 of 10
# Model Number: 234 with model UnobservedComponents in generation 1 of 10
# Model Number: 235 with model SeasonalNaive in generation 1 of 10
# Model Number: 236 with model SectionalMotif in generation 1 of 10
# Template Eval Error: ValueError("regression_type=='User' but no future_regressor supplied") in model 236: SectionalMotif
# Model Number: 237 with model LastValueNaive in generation 1 of 10
# Model Number: 238 with model ConstantNaive in generation 1 of 10
# Model Number: 239 with model UnivariateMotif in generation 1 of 10
# Model Number: 240 with model ARIMA in generation 1 of 10
# Model Number: 241 with model WindowRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 241: WindowRegression
# Model Number: 242 with model LastValueNaive in generation 1 of 10
# Model Number: 243 with model UnivariateMotif in generation 1 of 10
# Model Number: 244 with model AverageValueNaive in generation 1 of 10
# Model Number: 245 with model DatepartRegression in generation 1 of 10
# Model Number: 246 with model Theta in generation 1 of 10
# Model Number: 247 with model Theta in generation 1 of 10
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 247: Theta
# Model Number: 248 with model LastValueNaive in generation 1 of 10
# Model Number: 249 with model MultivariateMotif in generation 1 of 10
# Model Number: 250 with model WindowRegression in generation 1 of 10
# Model Number: 251 with model MultivariateRegression in generation 1 of 10
# Model Number: 252 with model Theta in generation 1 of 10
# No anomalies detected.
# Template Eval Error: Exception('Transformer HolidayTransformer failed on fit') in model 252: Theta
# Model Number: 253 with model ARIMA in generation 1 of 10
# Model Number: 254 with model Theta in generation 1 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 254: Theta
# Model Number: 255 with model SeasonalNaive in generation 1 of 10
# Model Number: 256 with model GLS in generation 1 of 10
# Model Number: 257 with model UnobservedComponents in generation 1 of 10
# Model Number: 258 with model GLS in generation 1 of 10
# Model Number: 259 with model AverageValueNaive in generation 1 of 10
# Model Number: 260 with model ETS in generation 1 of 10
# Model Number: 261 with model WindowRegression in generation 1 of 10
# Model Number: 262 with model Theta in generation 1 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 262: Theta
# Model Number: 263 with model MultivariateMotif in generation 1 of 10
# Model Number: 264 with model UnobservedComponents in generation 1 of 10
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:549: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Model Number: 265 with model SeasonalNaive in generation 1 of 10
# Model Number: 266 with model ETS in generation 1 of 10
# ETS error ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# ETS failed on Close with ValueError('endog must be strictly positive when usingmultiplicative trend or seasonal components.')
# Model Number: 267 with model ConstantNaive in generation 1 of 10
# Model Number: 268 with model DatepartRegression in generation 1 of 10
# Template Eval Error: ValueError("regression_type='User' but no future_regressor passed") in model 268: DatepartRegression
# Model Number: 269 with model UnobservedComponents in generation 1 of 10
# Model Number: 270 with model MultivariateRegression in generation 1 of 10
# [Parallel(n_jobs=-2)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 200 out of 200 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# Model Number: 271 with model MultivariateRegression in generation 1 of 10
# Model Number: 272 with model GLM in generation 1 of 10
# Template Eval Error: Exception('Transformer Cointegration failed on fit') in model 272: GLM
# Model Number: 273 with model SeasonalNaive in generation 1 of 10
# Model Number: 274 with model SeasonalNaive in generation 1 of 10
# Model Number: 275 with model WindowRegression in generation 1 of 10
# Model Number: 276 with model UnivariateRegression in generation 1 of 10
# Template Eval Error: ValueError("Input contains NaN, infinity or a value too large for dtype('float64').") in model 276: UnivariateRegression
# Model Number: 277 with model WindowRegression in generation 1 of 10
# Model Number: 278 with model UnivariateMotif in generation 1 of 10
# Model Number: 279 with model NVAR in generation 1 of 10
# Template Eval Error: Exception('Transformer BTCD failed on fit') in model 279: NVAR
# Model Number: 280 with model LastValueNaive in generation 1 of 10
# Model Number: 281 with model SectionalMotif in generation 1 of 10
# Model Number: 282 with model WindowRegression in generation 1 of 10
# Model Number: 283 with model ARIMA in generation 1 of 10
# Model Number: 284 with model MultivariateMotif in generation 1 of 10
# Model Number: 285 with model ARIMA in generation 1 of 10
# Model Number: 286 with model UnobservedComponents in generation 1 of 10
# Model Number: 287 with model ETS in generation 1 of 10
# Model Number: 288 with model NVAR in generation 1 of 10
# ...
# Model Number: 137 of 179 with model UnivariateRegression for Validation 3
# 137 - UnivariateRegression with avg smape 0.28:
# Model Number: 138 of 179 with model UnobservedComponents for Validation 3
# 138 - UnobservedComponents with avg smape 1.15:
# Model Number: 139 of 179 with model MultivariateRegression for Validation 3
# 139 - MultivariateRegression with avg smape 0.27:
# Model Number: 140 of 179 with model UnobservedComponents for Validation 3
# 140 - UnobservedComponents with avg smape 0.53:
# Model Number: 141 of 179 with model MultivariateRegression for Validation 3
# 141 - MultivariateRegression with avg smape 0.13:
# Model Number: 142 of 179 with model MultivariateRegression for Validation 3
# [Parallel(n_jobs=-2)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 200 out of 200 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# 142 - MultivariateRegression with avg smape 0.09:
# Model Number: 143 of 179 with model ConstantNaive for Validation 3
# 143 - ConstantNaive with avg smape 0.41:
# Model Number: 144 of 179 with model MultivariateRegression for Validation 3
# 144 - MultivariateRegression with avg smape 0.14:
# Model Number: 145 of 179 with model UnobservedComponents for Validation 3
# 145 - UnobservedComponents with avg smape 0.5:
# Model Number: 146 of 179 with model Theta for Validation 3
# 146 - Theta with avg smape 0.88:
# Model Number: 147 of 179 with model MultivariateRegression for Validation 3
# 147 - MultivariateRegression with avg smape 0.48:
# Model Number: 148 of 179 with model UnobservedComponents for Validation 3
# 148 - UnobservedComponents with avg smape 0.22:
# Model Number: 149 of 179 with model MultivariateRegression for Validation 3
# 149 - MultivariateRegression with avg smape 0.26:
# Model Number: 150 of 179 with model MultivariateRegression for Validation 3
# [Parallel(n_jobs=-2)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 200 out of 200 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# 150 - MultivariateRegression with avg smape 0.11:
# Model Number: 151 of 179 with model MultivariateRegression for Validation 3
# [Parallel(n_jobs=-2)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 200 out of 200 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    0.0s finished
# 151 - MultivariateRegression with avg smape 0.11:
# Model Number: 152 of 179 with model DatepartRegression for Validation 3
# /usr/local/lib/python3.7/dist-packages/scipy/signal/signaltools.py:1611: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# /usr/local/lib/python3.7/dist-packages/scipy/signal/signaltools.py:1611: RuntimeWarning:
#
# invalid value encountered in multiply
#
# [Parallel(n_jobs=-2)]: Using backend SequentialBackend with 1 concurrent workers.
# 152 - DatepartRegression with avg smape 0.33:
# Model Number: 153 of 179 with model ConstantNaive for Validation 3
# [Parallel(n_jobs=-2)]: Done 300 out of 300 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# 153 - ConstantNaive with avg smape 0.1:
# Model Number: 154 of 179 with model Theta for Validation 3
# 154 - Theta with avg smape 0.07:
# Model Number: 155 of 179 with model Theta for Validation 3
# 155 - Theta with avg smape 0.25:
# Model Number: 156 of 179 with model Theta for Validation 3
# 156 - Theta with avg smape 0.06:
# Model Number: 157 of 179 with model Theta for Validation 3
# 157 - Theta with avg smape 0.06:
# Model Number: 158 of 179 with model ConstantNaive for Validation 3
# 158 - ConstantNaive with avg smape 0.07:
# Model Number: 159 of 179 with model DatepartRegression for Validation 3
# 159 - DatepartRegression with avg smape 0.17:
# Model Number: 160 of 179 with model Theta for Validation 3
# 📈 160 - Theta with avg smape 0.04:
# Model Number: 161 of 179 with model Theta for Validation 3
# 161 - Theta with avg smape 0.04:
# Model Number: 162 of 179 with model Theta for Validation 3
# 162 - Theta with avg smape 0.05:
# Model Number: 163 of 179 with model Theta for Validation 3
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/nrf1jrt7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/k274j2xp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22050', 'data', 'file=/tmp/tmp1bm0dyn5/nrf1jrt7.json', 'init=/tmp/tmp1bm0dyn5/k274j2xp.json', 'output', 'file=/tmp/tmp8itrpm1p/prophet_model-20220921064209.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:42:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 163 - Theta with avg smape 0.05:
# Model Number: 164 of 179 with model FBProphet for Validation 3
# 06:42:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 164 - FBProphet with avg smape 1.25:
# Model Number: 165 of 179 with model ConstantNaive for Validation 3
# 165 - ConstantNaive with avg smape 0.54:
# Model Number: 166 of 179 with model DatepartRegression for Validation 3
# [Parallel(n_jobs=-2)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 300 out of 300 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 300 out of 300 | elapsed:    0.0s finished
# 166 - DatepartRegression with avg smape 0.1:
# Model Number: 167 of 179 with model DatepartRegression for Validation 3
# 167 - DatepartRegression with avg smape 0.33:
# Model Number: 168 of 179 with model DatepartRegression for Validation 3
# 168 - DatepartRegression with avg smape 0.1:
# Model Number: 169 of 179 with model DatepartRegression for Validation 3
# 169 - DatepartRegression with avg smape 0.12:
# Model Number: 170 of 179 with model DatepartRegression for Validation 3
# 170 - DatepartRegression with avg smape 0.12:
# Model Number: 171 of 179 with model DatepartRegression for Validation 3
# 171 - DatepartRegression with avg smape 0.19:
# Model Number: 172 of 179 with model ConstantNaive for Validation 3
# 172 - ConstantNaive with avg smape 0.07:
# Model Number: 173 of 179 with model FBProphet for Validation 3
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/qwndjto1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/ncyxmlvn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53978', 'data', 'file=/tmp/tmp1bm0dyn5/qwndjto1.json', 'init=/tmp/tmp1bm0dyn5/ncyxmlvn.json', 'output', 'file=/tmp/tmpj6est4g6/prophet_model-20220921064213.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:42:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:42:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/cuo6egv7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/gofid9bh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96827', 'data', 'file=/tmp/tmp1bm0dyn5/cuo6egv7.json', 'init=/tmp/tmp1bm0dyn5/gofid9bh.json', 'output', 'file=/tmp/tmpa51m4rov/prophet_model-20220921064215.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:42:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 173 - FBProphet with avg smape 0.1:
# Model Number: 174 of 179 with model FBProphet for Validation 3
# 06:42:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/3qxs8305.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/hxtz9d1d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31323', 'data', 'file=/tmp/tmp1bm0dyn5/3qxs8305.json', 'init=/tmp/tmp1bm0dyn5/hxtz9d1d.json', 'output', 'file=/tmp/tmpecr5k9jo/prophet_model-20220921064217.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:42:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 174 - FBProphet with avg smape 3.37:
# Model Number: 175 of 179 with model FBProphet for Validation 3
# 06:42:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/tmihz6jb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/s4yv2f7n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21493', 'data', 'file=/tmp/tmp1bm0dyn5/tmihz6jb.json', 'init=/tmp/tmp1bm0dyn5/s4yv2f7n.json', 'output', 'file=/tmp/tmpv3buygp3/prophet_model-20220921064219.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:42:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 175 - FBProphet with avg smape 4.06:
# Model Number: 176 of 179 with model FBProphet for Validation 3
# 06:42:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/7r9ilq9j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/7_w100qd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97217', 'data', 'file=/tmp/tmp1bm0dyn5/7r9ilq9j.json', 'init=/tmp/tmp1bm0dyn5/7_w100qd.json', 'output', 'file=/tmp/tmp3p64l12d/prophet_model-20220921064221.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:42:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 176 - FBProphet with avg smape 5.42:
# Model Number: 177 of 179 with model FBProphet for Validation 3
# 06:42:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/1aeimc33.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/sp3zoknt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62873', 'data', 'file=/tmp/tmp1bm0dyn5/1aeimc33.json', 'init=/tmp/tmp1bm0dyn5/sp3zoknt.json', 'output', 'file=/tmp/tmpq9rrwyou/prophet_model-20220921064224.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:42:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 177 - FBProphet with avg smape 6.3:
# Model Number: 178 of 179 with model FBProphet for Validation 3
# 06:42:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/qccipgb2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1bm0dyn5/hq_4fiuy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64719', 'data', 'file=/tmp/tmp1bm0dyn5/qccipgb2.json', 'init=/tmp/tmp1bm0dyn5/hq_4fiuy.json', 'output', 'file=/tmp/tmp2nv1ecsl/prophet_model-20220921064227.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:42:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 178 - FBProphet with avg smape 6.38:
# Model Number: 179 of 179 with model FBProphet for Validation 3
# 06:42:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 179 - FBProphet with avg smape 8.08:
#                 Close
# 2022-09-21  79.725899
# 2022-09-22  79.733973
# 2022-09-23  79.741770
# 2022-09-26  79.812698
# 2022-09-27  79.820902

# %%
print(forecast)
# Out:
#                 Close
# 2022-09-21  79.725899
# 2022-09-22  79.733973
# 2022-09-23  79.741770
# 2022-09-26  79.812698
# 2022-09-27  79.820902
